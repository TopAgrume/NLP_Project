# %% [markdown]
# # N-grams
#
# ## Import librairies

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/akaagi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import math
from collections import Counter, defaultdict
from nltk.tokenize import word_tokenize, sent_tokenize
import pandas as pd
pd.set_option('display.max_colwidth', None)
import re

# %% [markdown]
# ## Load dataset

# %%
# df_kaggle_poem_dataset = pd.read_csv("../data_raw/kaggle_poem_dataset.csv")
# df_kaggle_poem_dataset.drop(columns=["Unnamed: 0", "Author", "Title", "Poetry Foundation ID"], inplace=True)
# df_kaggle_poem_dataset.rename(columns={"Content": "poem"}, inplace=True)
# df_kaggle_poem_dataset.tail(3)
df_kaggle_poem_dataset = pd.read_csv("../data_raw/our_dataset.csv")
df_kaggle_poem_dataset.drop(columns=["Unnamed: 0", "topic"], inplace=True)
df_kaggle_poem_dataset.rename(columns={"Content": "poem"}, inplace=True)

# Define the remove_non_english function
def remove_non_english(text):
    # Regular expression to remove non-English alphabet characters
    english_only = re.sub(r'[^a-zA-Z\s.,;?!\'-]', '', text)
    return english_only

# Define the create_corpus function
def create_corpus(text):
    # Tokenize text into sentences
    sentences = text.split('\n')
    # Remove empty strings
    sentences = [sentence.strip() for sentence in sentences if sentence.strip()]
    # Join sentences into a corpus
    corpus = '\n'.join(sentences)  # Keep newline characters
    return corpus

# Read the CSV file
csv_path = "/home/akaagi/Desktop/SCIA/nlp1/NLP1_Project/data_raw/our_dataset.csv"
df = pd.read_csv(csv_path)

# Apply remove_non_english function to poem column
df['poem'] = df['poem'].apply(remove_non_english)

# Apply create_corpus function to poem column
df['poem'] = df['poem'].apply(create_corpus)

# Remove \xa0
df['poem'] = df['poem'].str.replace('\xa0', '')

# Apply lowercase to the poem column
df['poem'] = df['poem'].str.lower()

df_kaggle_poem_dataset.tail(3)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           poem
# 10061  I imagined the atmosphere would be clear, \nshot with pristine light, \nnot this sulphurous haze, \nthe air ionized as before a thunderstorm. \n\nMany have pictured a river here, \nbut no one mentioned all the boats, \ntheir benches crowded with naked passengers, \neach bent over a writing tablet. \n\nI knew I would not always be a child \nwith a model train and a model tunnel, \nand I knew I would not live forever, \njumping all day through the hoop of myself. \n\nI had heard about the journey to the other side \nand the clink of the final coin \nin the leather purse of the man holding the oar, \nbut how could anyone have guessed \n\nthat as soon as we arrived \nwe would be asked to describe this place \nand to include as much detail as possible— \nnot just the water, he insists, \n\nrather the oily, fathomless, rat-happy water, \nnot simply the shackles, but the rusty, \niron, ankle-shredding shackles— \nand that our next assignment would be \n\nto jot down, off the tops of our heads, \nour thoughts and feelings about being dead, \nnot really an assignment, \nthe man rotating the oar keeps telling us— \n\nthink of it more as an exercise, he groans, \nthink of writing as a process, \na never-ending, infernal process, \nand now the boats have become jammed together, \n\nbow against stern, stern locked to bow, \nand not a thing is moving, only our diligent pens.
# 10062                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Miss Nancy Ellicott\nStrode across the hills and broke them,\nRode across the hills and broke them—\nThe barren New England hills—\nRiding to hounds\nOver the cow-pasture.\n\nMiss Nancy Ellicott smoked\nAnd danced all the modern dances;\nAnd her aunts were not quite sure how they felt about it,\nBut they knew that it was modern.\n\nUpon the glazen shelves kept watch\nMatthew and Waldo, guardians of the faith,\nThe army of unalterable law.
# 10063                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               In the dark we disappear, pure being.\nOur mirror images, impure being.\n\nBeing and becoming (Heidegger), being and\nnothingness (Sartre)—which is purer being?\n\nBeing alone is no way to be: thus\nloneliness is the test of pure being.\n\nNights in love I fell too far or not quite\nfar enough—one pure, one impure being.\n\nClouds, snow, mist, the dragon's breath on water,\nsmoke from fire—a metaphor's pure being.\n\nStillness and more stillness and the light locked\ndeep inside—both pure and impure being.\n\nIs is the verb of being, I the noun—\nor pronoun for the purists of being.\n\nI was, I am, I looked within and saw\nnothing very clearly: purest being.

# %% [markdown]
# # Create corpus

# %%
corpus = " ".join(df_kaggle_poem_dataset['poem'])
corpus[:10]
# Out:
# 'Sunday we '

# %% [markdown]
# ## Tokenization

# %%
corpus = corpus.lower()
tokens = word_tokenize(corpus)
print("Number of tokens in the training set:",len(tokens))

vocab = set(tokens)
print("Vocabulary size:",len(vocab))
# Out:
# Number of tokens in the training set: 3391123
# Vocabulary size: 128887

# %% [markdown]
# ## Train n-grams

# %%
from collections import Counter, defaultdict
from nltk.tokenize import word_tokenize

def tokenize(text):
    """Tokenize the input text."""
    return word_tokenize(text)

def count_ngrams(tokens, n):
    """Counts n-grams."""
    ngrams = [tuple(tokens[i:i+n]) for i in range(len(tokens)-n+1)]
    return Counter(ngrams)

def calculate_ngram_probabilities(df, column, n, k=0.00001):
    """Calculates n-gram probabilities."""
    train_tokens = " ".join(df[column]).lower()
    train_tokens = tokenize(train_tokens)
    
    vocab = set(train_tokens)
    V = len(vocab)
    ngram_counts = count_ngrams(train_tokens, n)
    n_minus_one_gram_counts = count_ngrams(train_tokens, n-1)
    ngram_probabilities = defaultdict(float)
    
    for ngram in ngram_counts:
        prefix = ngram[:-1]
        ngram_counts[ngram] += k
        n_minus_one_gram_counts[prefix] += k
        ngram_probabilities[ngram] = (ngram_counts[ngram] + k) / (n_minus_one_gram_counts[prefix] + k*V)

    return ngram_probabilities

# %% [markdown]
# ## Example usage

# %%
n = 5  # n-gram size
k = 0.00001  # Change this to the desired value for smoothing parameter k

ngram_probabilities = calculate_ngram_probabilities(df_kaggle_poem_dataset, 'poem', n, k)

# %%
print(f"Number of {n}-grams:",len(ngram_probabilities))
# Out:
# Number of 5-grams: 3253229

# %%
ngram_probabilities
# Out:
# defaultdict(float,
#             {('sunday', 'we', 'lay', 'hands', 'on'): 0.4369036384607319,
#              ('we', 'lay', 'hands', 'on', 'a'): 0.4369036384607319,
#              ('lay', 'hands', 'on', 'a', 'girl'): 0.4369036384607319,
#              ('hands', 'on', 'a', 'girl', 'of'): 0.4369036384607319,
#              ('on', 'a', 'girl', 'of', 'ten'): 0.4369036384607319,
#              ('a', 'girl', 'of', 'ten', 'hand'): 0.4369036384607319,
#              ('girl', 'of', 'ten', 'hand', 'on'): 0.4369036384607319,
#              ('of', 'ten', 'hand', 'on', 'hand'): 0.4369036384607319,
#              ('ten', 'hand', 'on', 'hand', 'on'): 0.4369036384607319,
#              ('hand', 'on', 'hand', 'on', 'cornsilk'): 0.4369036384607319,
#              ('on', 'hand', 'on', 'cornsilk', 'hair'): 0.4369036384607319,
#              ('hand', 'on', 'cornsilk', 'hair', '.'): 0.4369036384607319,
#              ('on', 'cornsilk', 'hair', '.', 'we'): 0.4369036384607319,
#              ('cornsilk', 'hair', '.', 'we', 'sing'): 0.4369036384607319,
#              ('hair', '.', 'we', 'sing', 'the'): 0.4369036384607319,
#              ('.', 'we', 'sing', 'the', 'secret'): 0.4369036384607319,
#              ('we', 'sing', 'the', 'secret', 'language'): 0.4369036384607319,
#              ('sing', 'the', 'secret', 'language', 'sung'): 0.4369036384607319,
#              ('the', 'secret', 'language', 'sung', 'the'): 0.4369036384607319,
#              ('secret', 'language', 'sung', 'the', 'day'): 0.4369036384607319,
#              ('language', 'sung', 'the', 'day', 'the'): 0.4369036384607319,
#              ('sung', 'the', 'day', 'the', 'tin'): 0.4369036384607319,
#              ('the', 'day', 'the', 'tin', 'roof'): 0.4369036384607319,
#              ('day', 'the', 'tin', 'roof', 'of'): 0.4369036384607319,
#              ('the', 'tin', 'roof', 'of', 'the'): 0.4369036384607319,
#              ('tin', 'roof', 'of', 'the', 'tower'): 0.4369036384607319,
#              ('roof', 'of', 'the', 'tower', 'beat'): 0.4369036384607319,
#              ('of', 'the', 'tower', 'beat', 'on'): 0.4369036384607319,
#              ('the', 'tower', 'beat', 'on', 'god'): 0.4369036384607319,
#              ('tower', 'beat', 'on', 'god', '’'): 0.4369036384607319,
#              ('beat', 'on', 'god', '’', 's'): 0.4369036384607319,
#              ('on', 'god', '’', 's', 'floorboard'): 0.15901400567350626,
#              ('god', '’', 's', 'floorboard', 'he'): 0.4369036384607319,
#              ('’', 's', 'floorboard', 'he', 'got'): 0.4369036384607319,
#              ('s', 'floorboard', 'he', 'got', 'cramp'): 0.4369036384607319,
#              ('floorboard', 'he', 'got', 'cramp', 'in'): 0.4369036384607319,
#              ('he', 'got', 'cramp', 'in', 'heaven'): 0.4369036384607319,
#              ('got', 'cramp', 'in', 'heaven', '.'): 0.4369036384607319,
#              ('cramp', 'in', 'heaven', '.', 'like'): 0.4369036384607319,
#              ('in', 'heaven', '.', 'like', 'our'): 0.4369036384607319,
#              ('heaven', '.', 'like', 'our', 'crying'): 0.4369036384607319,
#              ('.', 'like', 'our', 'crying', 'and'): 0.4369036384607319,
#              ('like', 'our', 'crying', 'and', 'our'): 0.4369036384607319,
#              ('our',
#               'crying',
#               'and',
#               'our',
#               'fornicating'): 0.4369036384607319,
#              ('crying', 'and', 'our', 'fornicating', 'so'): 0.4369036384607319,
#              ('and', 'our', 'fornicating', 'so', 'close'): 0.4369036384607319,
#              ('our', 'fornicating', 'so', 'close', 'to'): 0.4369036384607319,
#              ('fornicating', 'so', 'close', 'to', 'his'): 0.4369036384607319,
#              ('so', 'close', 'to', 'his', 'bed'): 0.4369036384607319,
#              ('close', 'to', 'his', 'bed', 'was'): 0.4369036384607319,
#              ('to', 'his', 'bed', 'was', 'so'): 0.4369036384607319,
#              ('his', 'bed', 'was', 'so', 'many'): 0.4369036384607319,
#              ('bed', 'was', 'so', 'many', 'shrill'): 0.4369036384607319,
#              ('was', 'so', 'many', 'shrill', 'mice'): 0.4369036384607319,
#              ('so', 'many', 'shrill', 'mice', 'in'): 0.4369036384607319,
#              ('many', 'shrill', 'mice', 'in', 'a'): 0.4369036384607319,
#              ('shrill', 'mice', 'in', 'a', 'pretty'): 0.4369036384607319,
#              ('mice', 'in', 'a', 'pretty', 'pine'): 0.4369036384607319,
#              ('in', 'a', 'pretty', 'pine', 'floor'): 0.4369036384607319,
#              ('a', 'pretty', 'pine', 'floor', '.'): 0.4369036384607319,
#              ('pretty', 'pine', 'floor', '.', 'to'): 0.4369036384607319,
#              ('pine', 'floor', '.', 'to', 'heal'): 0.4369036384607319,
#              ('floor', '.', 'to', 'heal', 'the'): 0.4369036384607319,
#              ('.', 'to', 'heal', 'the', 'girl'): 0.4369036384607319,
#              ('to', 'heal', 'the', 'girl', 'with'): 0.4369036384607319,
#              ('heal', 'the', 'girl', 'with', 'the'): 0.4369036384607319,
#              ('the', 'girl', 'with', 'the', 'crippled'): 0.15901400567350626,
#              ('girl', 'with', 'the', 'crippled', 'up'): 0.4369036384607319,
#              ('with', 'the', 'crippled', 'up', 'leg'): 0.4369036384607319,
#              ('the', 'crippled', 'up', 'leg', 'god'): 0.4369036384607319,
#              ('crippled', 'up', 'leg', 'god', 'sends'): 0.4369036384607319,
#              ('up', 'leg', 'god', 'sends', 'back'): 0.4369036384607319,
#              ('leg', 'god', 'sends', 'back', 'the'): 0.4369036384607319,
#              ('god', 'sends', 'back', 'the', 'song'): 0.4369036384607319,
#              ('sends', 'back', 'the', 'song', 'he'): 0.4369036384607319,
#              ('back', 'the', 'song', 'he', 'took'): 0.4369036384607319,
#              ('the', 'song', 'he', 'took', 'and'): 0.4369036384607319,
#              ('song', 'he', 'took', 'and', 'down'): 0.4369036384607319,
#              ('he', 'took', 'and', 'down', 'it'): 0.4369036384607319,
#              ('took', 'and', 'down', 'it', 'comes'): 0.4369036384607319,
#              ('and', 'down', 'it', 'comes', 'contrary'): 0.4369036384607319,
#              ('down', 'it', 'comes', 'contrary', 'in'): 0.4369036384607319,
#              ('it', 'comes', 'contrary', 'in', 'one'): 0.4369036384607319,
#              ('comes', 'contrary', 'in', 'one', 'mouth'): 0.4369036384607319,
#              ('contrary', 'in', 'one', 'mouth', 'as'): 0.4369036384607319,
#              ('in', 'one', 'mouth', 'as', 'fire'): 0.4369036384607319,
#              ('one', 'mouth', 'as', 'fire', 'gentle'): 0.4369036384607319,
#              ('mouth', 'as', 'fire', 'gentle', 'on'): 0.4369036384607319,
#              ('as', 'fire', 'gentle', 'on', 'our'): 0.4369036384607319,
#              ('fire', 'gentle', 'on', 'our', 'bodies'): 0.4369036384607319,
#              ('gentle', 'on', 'our', 'bodies', 'as'): 0.4369036384607319,
#              ('on', 'our', 'bodies', 'as', 'rain'): 0.4369036384607319,
#              ('our', 'bodies', 'as', 'rain', '.'): 0.4369036384607319,
#              ('bodies', 'as', 'rain', '.', 'soft'): 0.4369036384607319,
#              ('as', 'rain', '.', 'soft', 'rain'): 0.4369036384607319,
#              ('rain', '.', 'soft', 'rain', 'swells'): 0.4369036384607319,
#              ('.', 'soft', 'rain', 'swells', 'the'): 0.4369036384607319,
#              ('soft',
#               'rain',
#               'swells',
#               'the',
#               'cumberland'): 0.4369036384607319,
#              ('rain',
#               'swells',
#               'the',
#               'cumberland',
#               'and'): 0.4369036384607319,
#              ('swells', 'the', 'cumberland', 'and', 'all'): 0.4369036384607319,
#              ('the', 'cumberland', 'and', 'all', 'her'): 0.4369036384607319,
#              ('cumberland', 'and', 'all', 'her', 'fields'): 0.4369036384607319,
#              ('and', 'all', 'her', 'fields', 'in'): 0.4369036384607319,
#              ('all', 'her', 'fields', 'in', 'april'): 0.4369036384607319,
#              ('her', 'fields', 'in', 'april', 'nuzzles'): 0.4369036384607319,
#              ('fields',
#               'in',
#               'april',
#               'nuzzles',
#               'buttercups'): 0.4369036384607319,
#              ('in',
#               'april',
#               'nuzzles',
#               'buttercups',
#               'the'): 0.4369036384607319,
#              ('april',
#               'nuzzles',
#               'buttercups',
#               'the',
#               'mules'): 0.4369036384607319,
#              ('nuzzles',
#               'buttercups',
#               'the',
#               'mules',
#               'won'): 0.4369036384607319,
#              ('buttercups', 'the', 'mules', 'won', '’'): 0.4369036384607319,
#              ('the', 'mules', 'won', '’', 't'): 0.4369036384607319,
#              ('mules', 'won', '’', 't', 'touch'): 0.4369036384607319,
#              ('won', '’', 't', 'touch', 'the'): 0.3040609569215052,
#              ('’', 't', 'touch', 'the', 'crowpoison'): 0.3040609569215052,
#              ('t', 'touch', 'the', 'crowpoison', 'the'): 0.4369036384607319,
#              ('touch',
#               'the',
#               'crowpoison',
#               'the',
#               'wake-robin'): 0.4369036384607319,
#              ('the',
#               'crowpoison',
#               'the',
#               'wake-robin',
#               'the'): 0.4369036384607319,
#              ('crowpoison',
#               'the',
#               'wake-robin',
#               'the',
#               'bluets'): 0.4369036384607319,
#              ('the', 'wake-robin', 'the', 'bluets', 'of'): 0.4369036384607319,
#              ('wake-robin', 'the', 'bluets', 'of', 'the'): 0.4369036384607319,
#              ('the', 'bluets', 'of', 'the', 'field'): 0.4369036384607319,
#              ('bluets', 'of', 'the', 'field', '.'): 0.4369036384607319,
#              ('of', 'the', 'field', '.', 'every'): 0.23316576821920873,
#              ('the', 'field', '.', 'every', 'song'): 0.4369036384607319,
#              ('field', '.', 'every', 'song', 'got'): 0.4369036384607319,
#              ('.', 'every', 'song', 'got', 'a'): 0.4369036384607319,
#              ('every', 'song', 'got', 'a', 'beat'): 0.4369036384607319,
#              ('song', 'got', 'a', 'beat', 'beneath'): 0.4369036384607319,
#              ('got', 'a', 'beat', 'beneath', '.'): 0.4369036384607319,
#              ('a', 'beat', 'beneath', '.', 'start'): 0.4369036384607319,
#              ('beat', 'beneath', '.', 'start', 'with'): 0.4369036384607319,
#              ('beneath', '.', 'start', 'with', 'the'): 0.4369036384607319,
#              ('.', 'start', 'with', 'the', 'whippoorwill'): 0.4369036384607319,
#              ('start',
#               'with',
#               'the',
#               'whippoorwill',
#               'early'): 0.4369036384607319,
#              ('with',
#               'the',
#               'whippoorwill',
#               'early',
#               'meadow'): 0.4369036384607319,
#              ('the',
#               'whippoorwill',
#               'early',
#               'meadow',
#               'colors'): 0.4369036384607319,
#              ('whippoorwill',
#               'early',
#               'meadow',
#               'colors',
#               'creep'): 0.4369036384607319,
#              ('early',
#               'meadow',
#               'colors',
#               'creep',
#               'into'): 0.4369036384607319,
#              ('meadow', 'colors', 'creep', 'into', 'the'): 0.4369036384607319,
#              ('colors', 'creep', 'into', 'the', 'sky'): 0.4369036384607319,
#              ('creep', 'into', 'the', 'sky', '.'): 0.4369036384607319,
#              ('into', 'the', 'sky', '.', 'my'): 0.13719803316833315,
#              ('the', 'sky', '.', 'my', 'sons'): 0.18907972954576396,
#              ('sky', '.', 'my', 'sons', 'made'): 0.4369036384607319,
#              ('.', 'my', 'sons', 'made', 'this'): 0.4369036384607319,
#              ('my', 'sons', 'made', 'this', 'tobacco'): 0.4369036384607319,
#              ('sons', 'made', 'this', 'tobacco', 'sled'): 0.4369036384607319,
#              ('made', 'this', 'tobacco', 'sled', 'i'): 0.4369036384607319,
#              ('this', 'tobacco', 'sled', 'i', 'prime'): 0.4369036384607319,
#              ('tobacco', 'sled', 'i', 'prime', 'with'): 0.4369036384607319,
#              ('sled', 'i', 'prime', 'with', 'the'): 0.4369036384607319,
#              ('i', 'prime', 'with', 'the', 'jenny'): 0.4369036384607319,
#              ('prime', 'with', 'the', 'jenny', 'toss'): 0.4369036384607319,
#              ('with', 'the', 'jenny', 'toss', 'the'): 0.4369036384607319,
#              ('the', 'jenny', 'toss', 'the', 'last'): 0.4369036384607319,
#              ('jenny', 'toss', 'the', 'last', 'of'): 0.4369036384607319,
#              ('toss', 'the', 'last', 'of', 'the'): 0.4369036384607319,
#              ('the', 'last', 'of', 'the', 'sandlugs'): 0.05784180351763678,
#              ('last', 'of', 'the', 'sandlugs', 'for'): 0.4369036384607319,
#              ('of', 'the', 'sandlugs', 'for', 'the'): 0.4369036384607319,
#              ('the', 'sandlugs', 'for', 'the', 'rest'): 0.4369036384607319,
#              ('sandlugs', 'for', 'the', 'rest', 'to'): 0.4369036384607319,
#              ('for', 'the', 'rest', 'to', 'thrive'): 0.4369036384607319,
#              ('the', 'rest', 'to', 'thrive', '.'): 0.4369036384607319,
#              ('rest', 'to', 'thrive', '.', 'so'): 0.4369036384607319,
#              ('to', 'thrive', '.', 'so', 'hot'): 0.4369036384607319,
#              ('thrive', '.', 'so', 'hot', 'the'): 0.4369036384607319,
#              ('.', 'so', 'hot', 'the', 'wasps'): 0.4369036384607319,
#              ('so', 'hot', 'the', 'wasps', 'hang'): 0.4369036384607319,
#              ('hot', 'the', 'wasps', 'hang', 'on'): 0.4369036384607319,
#              ('the', 'wasps', 'hang', 'on', 'the'): 0.4369036384607319,
#              ('wasps', 'hang', 'on', 'the', 'honeysuckle'): 0.4369036384607319,
#              ('hang', 'on', 'the', 'honeysuckle', 'too'): 0.4369036384607319,
#              ('on', 'the', 'honeysuckle', 'too', 'spent'): 0.4369036384607319,
#              ('the', 'honeysuckle', 'too', 'spent', 'to'): 0.4369036384607319,
#              ('honeysuckle', 'too', 'spent', 'to', 'buzz'): 0.4369036384607319,
#              ('too', 'spent', 'to', 'buzz', 'a'): 0.4369036384607319,
#              ('spent', 'to', 'buzz', 'a', 'sermon'): 0.4369036384607319,
#              ('to', 'buzz', 'a', 'sermon', '.'): 0.4369036384607319,
#              ('buzz', 'a', 'sermon', '.', 'i'): 0.4369036384607319,
#              ('a', 'sermon', '.', 'i', 'know'): 0.4369036384607319,
#              ('sermon', '.', 'i', 'know', 'my'): 0.4369036384607319,
#              ('.', 'i', 'know', 'my', 'song'): 0.09719425243563927,
#              ('i', 'know', 'my', 'song', 'remembers'): 0.4369036384607319,
#              ('know', 'my', 'song', 'remembers', 'what'): 0.4369036384607319,
#              ('my', 'song', 'remembers', 'what', 'my'): 0.4369036384607319,
#              ('song',
#               'remembers',
#               'what',
#               'my',
#               'fathers'): 0.4369036384607319,
#              ('remembers',
#               'what',
#               'my',
#               'fathers',
#               'told'): 0.4369036384607319,
#              ('what', 'my', 'fathers', 'told', 'their'): 0.4369036384607319,
#              ('my', 'fathers', 'told', 'their', 'strings'): 0.4369036384607319,
#              ('fathers', 'told', 'their', 'strings', '.'): 0.4369036384607319,
#              ('told', 'their', 'strings', '.', 'driskill'): 0.4369036384607319,
#              ('their', 'strings', '.', 'driskill', ','): 0.4369036384607319,
#              ('strings',
#               '.',
#               'driskill',
#               ',',
#               'kentuckydriskill'): 0.4369036384607319,
#              ('.',
#               'driskill',
#               ',',
#               'kentuckydriskill',
#               ','): 0.4369036384607319,
#              ('driskill',
#               ',',
#               'kentuckydriskill',
#               ',',
#               'kentucky'): 0.4369036384607319,
#              (',',
#               'kentuckydriskill',
#               ',',
#               'kentucky',
#               'o'): 0.4369036384607319,
#              ('kentuckydriskill',
#               ',',
#               'kentucky',
#               'o',
#               'transient'): 0.4369036384607319,
#              (',',
#               'kentucky',
#               'o',
#               'transient',
#               'voyager'): 0.4369036384607319,
#              ('kentucky',
#               'o',
#               'transient',
#               'voyager',
#               'of'): 0.4369036384607319,
#              ('o', 'transient', 'voyager', 'of', 'heaven'): 0.4369036384607319,
#              ('transient', 'voyager', 'of', 'heaven', '!'): 0.4369036384607319,
#              ('voyager', 'of', 'heaven', '!', '\u2060'): 0.4369036384607319,
#              ('of', 'heaven', '!', '\u2060', '\u2060'): 0.4369036384607319,
#              ('heaven', '!', '\u2060', '\u2060', '\u2060'): 0.4369036384607319,
#              ('!', '\u2060', '\u2060', '\u2060', 'o'): 0.4369036384607319,
#              ('\u2060', '\u2060', '\u2060', 'o', 'silent'): 0.4369036384607319,
#              ('\u2060', '\u2060', 'o', 'silent', 'sign'): 0.4369036384607319,
#              ('\u2060', 'o', 'silent', 'sign', 'of'): 0.4369036384607319,
#              ('o', 'silent', 'sign', 'of', 'winter'): 0.4369036384607319,
#              ('silent', 'sign', 'of', 'winter', 'skies'): 0.4369036384607319,
#              ('sign', 'of', 'winter', 'skies', '!'): 0.4369036384607319,
#              ('of', 'winter', 'skies', '!', 'what'): 0.4369036384607319,
#              ('winter', 'skies', '!', 'what', 'adverse'): 0.4369036384607319,
#              ('skies', '!', 'what', 'adverse', 'wind'): 0.4369036384607319,
#              ('!', 'what', 'adverse', 'wind', 'thy'): 0.4369036384607319,
#              ('what', 'adverse', 'wind', 'thy', 'sail'): 0.4369036384607319,
#              ('adverse', 'wind', 'thy', 'sail', 'has'): 0.4369036384607319,
#              ('wind', 'thy', 'sail', 'has', 'driven'): 0.4369036384607319,
#              ('thy', 'sail', 'has', 'driven', '\u2060'): 0.4369036384607319,
#              ('sail', 'has', 'driven', '\u2060', '\u2060'): 0.4369036384607319,
#              ('has',
#               'driven',
#               '\u2060',
#               '\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('driven',
#               '\u2060',
#               '\u2060',
#               '\u2060',
#               'to'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060',
#               'to',
#               'dungeons'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               'to',
#               'dungeons',
#               'where'): 0.4369036384607319,
#              ('\u2060', 'to', 'dungeons', 'where', 'a'): 0.4369036384607319,
#              ('to', 'dungeons', 'where', 'a', 'prisoner'): 0.4369036384607319,
#              ('dungeons',
#               'where',
#               'a',
#               'prisoner',
#               'lies'): 0.4369036384607319,
#              ('where', 'a', 'prisoner', 'lies', '?'): 0.4369036384607319,
#              ('a', 'prisoner', 'lies', '?', 'methinks'): 0.4369036384607319,
#              ('prisoner', 'lies', '?', 'methinks', 'the'): 0.4369036384607319,
#              ('lies', '?', 'methinks', 'the', 'hands'): 0.4369036384607319,
#              ('?', 'methinks', 'the', 'hands', 'that'): 0.4369036384607319,
#              ('methinks', 'the', 'hands', 'that', 'shut'): 0.4369036384607319,
#              ('the', 'hands', 'that', 'shut', 'the'): 0.4369036384607319,
#              ('hands', 'that', 'shut', 'the', 'sun'): 0.4369036384607319,
#              ('that', 'shut', 'the', 'sun', '\u2060'): 0.4369036384607319,
#              ('shut', 'the', 'sun', '\u2060', '\u2060'): 0.4369036384607319,
#              ('the', 'sun', '\u2060', '\u2060', '\u2060'): 0.4369036384607319,
#              ('sun',
#               '\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060so'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060so',
#               'sternly'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060so',
#               'sternly',
#               'from'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060so',
#               'sternly',
#               'from',
#               'this'): 0.4369036384607319,
#              ('\u2060so',
#               'sternly',
#               'from',
#               'this',
#               'morning'): 0.4369036384607319,
#              ('sternly', 'from', 'this', 'morning', "'s"): 0.4369036384607319,
#              ('from', 'this', 'morning', "'s", 'brow'): 0.4369036384607319,
#              ('this', 'morning', "'s", 'brow', 'might'): 0.4369036384607319,
#              ('morning', "'s", 'brow', 'might', 'still'): 0.4369036384607319,
#              ("'s", 'brow', 'might', 'still', 'their'): 0.4369036384607319,
#              ('brow', 'might', 'still', 'their', 'rebel'): 0.4369036384607319,
#              ('might', 'still', 'their', 'rebel', 'task'): 0.4369036384607319,
#              ('still', 'their', 'rebel', 'task', 'have'): 0.4369036384607319,
#              ('their', 'rebel', 'task', 'have', 'done'): 0.4369036384607319,
#              ('rebel',
#               'task',
#               'have',
#               'done',
#               '\u2060\u2060'): 0.4369036384607319,
#              ('task',
#               'have',
#               'done',
#               '\u2060\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('have',
#               'done',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('done',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'and'): 0.4369036384607319,
#              ('\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'and',
#               'checked'): 0.3040609569215052,
#              ('\u2060', '\u2060', 'and', 'checked', 'a'): 0.4369036384607319,
#              ('\u2060', 'and', 'checked', 'a', 'thing'): 0.4369036384607319,
#              ('and', 'checked', 'a', 'thing', 'so'): 0.4369036384607319,
#              ('checked', 'a', 'thing', 'so', 'frail'): 0.4369036384607319,
#              ('a', 'thing', 'so', 'frail', 'as'): 0.4369036384607319,
#              ('thing', 'so', 'frail', 'as', 'thou'): 0.4369036384607319,
#              ('so', 'frail', 'as', 'thou', '.'): 0.4369036384607319,
#              ('frail', 'as', 'thou', '.', 'they'): 0.4369036384607319,
#              ('as', 'thou', '.', 'they', 'would'): 0.4369036384607319,
#              ('thou', '.', 'they', 'would', 'have'): 0.4369036384607319,
#              ('.', 'they', 'would', 'have', 'done'): 0.3040609569215052,
#              ('they', 'would', 'have', 'done', 'it'): 0.4369036384607319,
#              ('would', 'have', 'done', 'it', 'had'): 0.23316576821920873,
#              ('have', 'done', 'it', 'had', 'they'): 0.4369036384607319,
#              ('done', 'it', 'had', 'they', 'known'): 0.4369036384607319,
#              ('it', 'had', 'they', 'known', '\u2060'): 0.4369036384607319,
#              ('had', 'they', 'known', '\u2060', '\u2060'): 0.4369036384607319,
#              ('they',
#               'known',
#               '\u2060',
#               '\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('known',
#               '\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060the'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060the',
#               'talisman'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060the',
#               'talisman',
#               'that'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060the',
#               'talisman',
#               'that',
#               'dwelt'): 0.4369036384607319,
#              ('\u2060the',
#               'talisman',
#               'that',
#               'dwelt',
#               'in'): 0.4369036384607319,
#              ('talisman', 'that', 'dwelt', 'in', 'thee'): 0.4369036384607319,
#              ('that', 'dwelt', 'in', 'thee', ','): 0.4369036384607319,
#              ('dwelt', 'in', 'thee', ',', 'for'): 0.4369036384607319,
#              ('in', 'thee', ',', 'for', 'all'): 0.23316576821920873,
#              ('thee', ',', 'for', 'all', 'the'): 0.4369036384607319,
#              (',', 'for', 'all', 'the', 'suns'): 0.06139280294286656,
#              ('for', 'all', 'the', 'suns', 'that'): 0.4369036384607319,
#              ('all', 'the', 'suns', 'that', 'ever'): 0.4369036384607319,
#              ('the', 'suns', 'that', 'ever', 'shone'): 0.4369036384607319,
#              ('suns', 'that', 'ever', 'shone', '\u2060'): 0.4369036384607319,
#              ('that', 'ever', 'shone', '\u2060', '\u2060'): 0.4369036384607319,
#              ('ever',
#               'shone',
#               '\u2060',
#               '\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('shone',
#               '\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060have'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060have',
#               'never'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060have',
#               'never',
#               'been'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060have',
#               'never',
#               'been',
#               'so'): 0.4369036384607319,
#              ('\u2060have', 'never', 'been', 'so', 'kind'): 0.4369036384607319,
#              ('never', 'been', 'so', 'kind', 'to'): 0.4369036384607319,
#              ('been', 'so', 'kind', 'to', 'me'): 0.4369036384607319,
#              ('so', 'kind', 'to', 'me', '!'): 0.4369036384607319,
#              ('kind', 'to', 'me', '!', 'for'): 0.3040609569215052,
#              ('to', 'me', '!', 'for', 'many'): 0.4369036384607319,
#              ('me', '!', 'for', 'many', 'a'): 0.4369036384607319,
#              ('!', 'for', 'many', 'a', 'week'): 0.4369036384607319,
#              ('for', 'many', 'a', 'week', ','): 0.4369036384607319,
#              ('many', 'a', 'week', ',', 'and'): 0.4369036384607319,
#              ('a', 'week', ',', 'and', 'many'): 0.18907972954576396,
#              ('week', ',', 'and', 'many', 'a'): 0.4369036384607319,
#              (',', 'and', 'many', 'a', 'day'): 0.06139280294286656,
#              ('and', 'many', 'a', 'day', '\u2060\u2060'): 0.23316576821920873,
#              ('many',
#               'a',
#               'day',
#               '\u2060\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('a',
#               'day',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('day',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'my'): 0.4369036384607319,
#              ('\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'my',
#               'heart'): 0.4369036384607319,
#              ('\u2060', '\u2060', 'my', 'heart', 'was'): 0.4369036384607319,
#              ('\u2060', 'my', 'heart', 'was', 'weighed'): 0.4369036384607319,
#              ('my', 'heart', 'was', 'weighed', 'with'): 0.4369036384607319,
#              ('heart',
#               'was',
#               'weighed',
#               'with',
#               'sinking'): 0.4369036384607319,
#              ('was',
#               'weighed',
#               'with',
#               'sinking',
#               'gloom'): 0.4369036384607319,
#              ('weighed',
#               'with',
#               'sinking',
#               'gloom',
#               'when'): 0.4369036384607319,
#              ('with',
#               'sinking',
#               'gloom',
#               'when',
#               'morning'): 0.4369036384607319,
#              ('sinking',
#               'gloom',
#               'when',
#               'morning',
#               'rose'): 0.4369036384607319,
#              ('gloom', 'when', 'morning', 'rose', 'in'): 0.4369036384607319,
#              ('when', 'morning', 'rose', 'in', 'mourning'): 0.4369036384607319,
#              ('morning', 'rose', 'in', 'mourning', 'grey'): 0.4369036384607319,
#              ('rose',
#               'in',
#               'mourning',
#               'grey',
#               '\u2060\u2060'): 0.4369036384607319,
#              ('in',
#               'mourning',
#               'grey',
#               '\u2060\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('mourning',
#               'grey',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('grey',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'and'): 0.4369036384607319,
#              ('\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'and',
#               'faintly'): 0.30406003241215124,
#              ('\u2060', '\u2060', 'and', 'faintly', 'lit'): 0.4369036384607319,
#              ('\u2060', 'and', 'faintly', 'lit', 'my'): 0.4369036384607319,
#              ('and', 'faintly', 'lit', 'my', 'prison'): 0.4369036384607319,
#              ('faintly', 'lit', 'my', 'prison', 'room'): 0.4369036384607319,
#              ('lit', 'my', 'prison', 'room', 'but'): 0.4369036384607319,
#              ('my', 'prison', 'room', 'but', 'angel'): 0.4369036384607319,
#              ('prison', 'room', 'but', 'angel', 'like'): 0.4369036384607319,
#              ('room', 'but', 'angel', 'like', ','): 0.4369036384607319,
#              ('but', 'angel', 'like', ',', 'when'): 0.4369036384607319,
#              ('angel', 'like', ',', 'when', 'i'): 0.4369036384607319,
#              ('like', ',', 'when', 'i', 'awoke'): 0.3040609569215052,
#              (',', 'when', 'i', 'awoke', ','): 0.4369036384607319,
#              ('when', 'i', 'awoke', ',', '\u2060\u2060'): 0.18907972954576396,
#              ('i', 'awoke', ',', '\u2060\u2060', '\u2060'): 0.4369036384607319,
#              ('awoke',
#               ',',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060'): 0.4369036384607319,
#              (',',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'thy'): 0.4369036384607319,
#              ('\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'thy',
#               'silvery'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               'thy',
#               'silvery',
#               'form'): 0.4369036384607319,
#              ('\u2060', 'thy', 'silvery', 'form', ','): 0.4369036384607319,
#              ('thy', 'silvery', 'form', ',', 'so'): 0.4369036384607319,
#              ('silvery', 'form', ',', 'so', 'soft'): 0.4369036384607319,
#              ('form', ',', 'so', 'soft', 'and'): 0.4369036384607319,
#              (',', 'so', 'soft', 'and', 'fair'): 0.4369036384607319,
#              ('so', 'soft', 'and', 'fair', 'shining'): 0.4369036384607319,
#              ('soft', 'and', 'fair', 'shining', 'through'): 0.4369036384607319,
#              ('and',
#               'fair',
#               'shining',
#               'through',
#               'darkness'): 0.4369036384607319,
#              ('fair',
#               'shining',
#               'through',
#               'darkness',
#               ','): 0.4369036384607319,
#              ('shining',
#               'through',
#               'darkness',
#               ',',
#               'sweetly'): 0.4369036384607319,
#              ('through',
#               'darkness',
#               ',',
#               'sweetly',
#               'spoke'): 0.4369036384607319,
#              ('darkness',
#               ',',
#               'sweetly',
#               'spoke',
#               '\u2060\u2060'): 0.4369036384607319,
#              (',',
#               'sweetly',
#               'spoke',
#               '\u2060\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('sweetly',
#               'spoke',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('spoke',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'of'): 0.4369036384607319,
#              ('\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'of',
#               'cloudy'): 0.4369036384607319,
#              ('\u2060', '\u2060', 'of', 'cloudy', 'skies'): 0.4369036384607319,
#              ('\u2060', 'of', 'cloudy', 'skies', 'and'): 0.4369036384607319,
#              ('of', 'cloudy', 'skies', 'and', 'mountains'): 0.4369036384607319,
#              ('cloudy',
#               'skies',
#               'and',
#               'mountains',
#               'bare'): 0.4369036384607319,
#              ('skies', 'and', 'mountains', 'bare', ';'): 0.4369036384607319,
#              ('and', 'mountains', 'bare', ';', 'the'): 0.4369036384607319,
#              ('mountains', 'bare', ';', 'the', 'dearest'): 0.4369036384607319,
#              ('bare', ';', 'the', 'dearest', 'to'): 0.4369036384607319,
#              (';', 'the', 'dearest', 'to', 'a'): 0.4369036384607319,
#              ('the', 'dearest', 'to', 'a', 'mountaineer'): 0.4369036384607319,
#              ('dearest',
#               'to',
#               'a',
#               'mountaineer',
#               '\u2060\u2060'): 0.4369036384607319,
#              ('to',
#               'a',
#               'mountaineer',
#               '\u2060\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('a',
#               'mountaineer',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('mountaineer',
#               '\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'who'): 0.4369036384607319,
#              ('\u2060\u2060',
#               '\u2060',
#               '\u2060',
#               'who',
#               ','): 0.4369036384607319,
#              ('\u2060', '\u2060', 'who', ',', 'all'): 0.4369036384607319,
#              ('\u2060', 'who', ',', 'all', 'life'): 0.4369036384607319,
#              ('who', ',', 'all', 'life', 'long'): 0.4369036384607319,
#              (',', 'all', 'life', 'long', 'has'): 0.4369036384607319,
#              ('all', 'life', 'long', 'has', 'loved'): 0.4369036384607319,
#              ('life', 'long', 'has', 'loved', 'the'): 0.4369036384607319,
#              ('long', 'has', 'loved', 'the', 'snow'): 0.4369036384607319,
#              ('has', 'loved', 'the', 'snow', 'that'): 0.4369036384607319,
#              ('loved', 'the', 'snow', 'that', 'crowned'): 0.4369036384607319,
#              ('the', 'snow', 'that', 'crowned', 'his'): 0.4369036384607319,
#              ('snow', 'that', 'crowned', 'his', 'native'): 0.4369036384607319,
#              ('that',
#               'crowned',
#               'his',
#               'native',
#               'summits'): 0.4369036384607319,
#              ('crowned',
#               'his',
#               'native',
#               'summits',
#               'drear'): 0.4369036384607319,
#              ('his', 'native', 'summits', 'drear', ','): 0.4369036384607319,
#              ('native', 'summits', 'drear', ',', '\u2060'): 0.4369036384607319,
#              ('summits', 'drear', ',', '\u2060', '\u2060'): 0.4369036384607319,
#              ('drear', ',', '\u2060', '\u2060', '\u2060'): 0.4369036384607319,
#              (',',
#               '\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060better'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060better',
#               ','): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060better',
#               ',',
#               'than'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060better',
#               ',',
#               'than',
#               'greenest'): 0.4369036384607319,
#              ('\u2060better',
#               ',',
#               'than',
#               'greenest',
#               'plains'): 0.4369036384607319,
#              (',', 'than', 'greenest', 'plains', 'below'): 0.4369036384607319,
#              ('than', 'greenest', 'plains', 'below', '.'): 0.4369036384607319,
#              ('greenest', 'plains', 'below', '.', 'and'): 0.4369036384607319,
#              ('plains', 'below', '.', 'and', 'voiceless'): 0.4369036384607319,
#              ('below', '.', 'and', 'voiceless', ','): 0.4369036384607319,
#              ('.', 'and', 'voiceless', ',', 'soulless'): 0.4369036384607319,
#              ('and', 'voiceless', ',', 'soulless', ','): 0.4369036384607319,
#              ('voiceless',
#               ',',
#               'soulless',
#               ',',
#               'messenger'): 0.4369036384607319,
#              (',', 'soulless', ',', 'messenger', '\u2060'): 0.4369036384607319,
#              ('soulless',
#               ',',
#               'messenger',
#               '\u2060',
#               '\u2060'): 0.4369036384607319,
#              (',',
#               'messenger',
#               '\u2060',
#               '\u2060',
#               '\u2060'): 0.4369036384607319,
#              ('messenger',
#               '\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060thy'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060thy',
#               'presence'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060thy',
#               'presence',
#               'waked'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060thy',
#               'presence',
#               'waked',
#               'a'): 0.4369036384607319,
#              ('\u2060thy',
#               'presence',
#               'waked',
#               'a',
#               'thrilling'): 0.4369036384607319,
#              ('presence',
#               'waked',
#               'a',
#               'thrilling',
#               'tone'): 0.4369036384607319,
#              ('waked', 'a', 'thrilling', 'tone', 'that'): 0.4369036384607319,
#              ('a',
#               'thrilling',
#               'tone',
#               'that',
#               'comforts'): 0.4369036384607319,
#              ('thrilling',
#               'tone',
#               'that',
#               'comforts',
#               'me'): 0.4369036384607319,
#              ('tone', 'that', 'comforts', 'me', 'while'): 0.4369036384607319,
#              ('that', 'comforts', 'me', 'while', 'thou'): 0.4369036384607319,
#              ('comforts', 'me', 'while', 'thou', 'art'): 0.4369036384607319,
#              ('me', 'while', 'thou', 'art', 'here'): 0.4369036384607319,
#              ('while', 'thou', 'art', 'here', '\u2060'): 0.4369036384607319,
#              ('thou', 'art', 'here', '\u2060', '\u2060'): 0.4369036384607319,
#              ('art', 'here', '\u2060', '\u2060', '\u2060'): 0.4369036384607319,
#              ('here',
#               '\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060and'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060',
#               '\u2060and',
#               'will'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060',
#               '\u2060and',
#               'will',
#               'sustain'): 0.4369036384607319,
#              ('\u2060',
#               '\u2060and',
#               'will',
#               'sustain',
#               'when'): 0.4369036384607319,
#              ('\u2060and',
#               'will',
#               'sustain',
#               'when',
#               'thou'): 0.4369036384607319,
#              ('will', 'sustain', 'when', 'thou', 'art'): 0.4369036384607319,
#              ('sustain', 'when', 'thou', 'art', 'gone'): 0.4369036384607319,
#              ('when', 'thou', 'art', 'gone', 'a'): 0.23316576821920873,
#              ('thou', 'art', 'gone', 'a', 'cento'): 0.4369036384607319,
#              ('art', 'gone', 'a', 'cento', 'for'): 0.4369036384607319,
#              ('gone', 'a', 'cento', 'for', 'sarah'): 0.4369036384607319,
#              ('a', 'cento', 'for', 'sarah', 'hegazy'): 0.4663268732163175,
#              ('cento', 'for', 'sarah', 'hegazy', 'a'): 0.6081158327454939,
#              ('for', 'sarah', 'hegazy', 'a', 'cento'): 0.6081158327454939,
#              ('sarah', 'hegazy', 'a', 'cento', 'for'): 0.6081158327454939,
#              ('hegazy', 'a', 'cento', 'for', 'sarah'): 0.6081158327454939,
#              ('a', 'cento', 'for', 'sarah', 'hegazyin'): 0.23316522456859468,
#              ('cento', 'for', 'sarah', 'hegazyin', 'the'): 0.4369036384607319,
#              ('for', 'sarah', 'hegazyin', 'the', 'hiding'): 0.4369036384607319,
#              ('sarah',
#               'hegazyin',
#               'the',
#               'hiding',
#               'hour'): 0.4369036384607319,
#              ('hegazyin', 'the', 'hiding', 'hour', 'of'): 0.4369036384607319,
#              ('the', 'hiding', 'hour', 'of', 'autophagy'): 0.4369036384607319,
#              ('hiding',
#               'hour',
#               'of',
#               'autophagy',
#               'ghosts'): 0.4369036384607319,
#              ('hour', 'of', 'autophagy', 'ghosts', 'hang'): 0.4369036384607319,
#              ('of', 'autophagy', 'ghosts', 'hang', 'out'): 0.4369036384607319,
#              ('autophagy', 'ghosts', 'hang', 'out', 'all'): 0.4369036384607319,
#              ('ghosts', 'hang', 'out', 'all', 'day'): 0.4369036384607319,
#              ('hang', 'out', 'all', 'day', 'and'): 0.4369036384607319,
#              ('out', 'all', 'day', 'and', 'talk'): 0.4369036384607319,
#              ('all', 'day', 'and', 'talk', 'to'): 0.4369036384607319,
#              ('day', 'and', 'talk', 'to', 'us'): 0.4369036384607319,
#              ('and', 'talk', 'to', 'us', '.'): 0.4369036384607319,
#              ('talk', 'to', 'us', '.', 'an'): 0.4369036384607319,
#              ('to', 'us', '.', 'an', 'archival'): 0.4369036384607319,
#              ('us', '.', 'an', 'archival', 'haunting'): 0.4369036384607319,
#              ('.',
#               'an',
#               'archival',
#               'haunting',
#               'demanding'): 0.4369036384607319,
#              ('an',
#               'archival',
#               'haunting',
#               'demanding',
#               'tribute'): 0.4369036384607319,
#              ('archival',
#               'haunting',
#               'demanding',
#               'tribute',
#               ':'): 0.4369036384607319,
#              ('haunting',
#               'demanding',
#               'tribute',
#               ':',
#               'half'): 0.4369036384607319,
#              ('demanding', 'tribute', ':', 'half', 'a'): 0.4369036384607319,
#              ('tribute', ':', 'half', 'a', 'lime'): 0.4369036384607319,
#              (':', 'half', 'a', 'lime', 'for'): 0.4369036384607319,
#              ('half', 'a', 'lime', 'for', 'breakfast'): 0.4369036384607319,
#              ('a', 'lime', 'for', 'breakfast', 'every'): 0.4369036384607319,
#              ('lime', 'for', 'breakfast', 'every', 'day'): 0.4369036384607319,
#              ('for', 'breakfast', 'every', 'day', '.'): 0.4369036384607319,
#              ('breakfast', 'every', 'day', '.', 'بشرٌ'): 0.4369036384607319,
#              ('every', 'day', '.', 'بشرٌ', 'يئنّونَ'): 0.4369036384607319,
#              ('day', '.', 'بشرٌ', 'يئنّونَ', 'من'): 0.4369036384607319,
#              ('.', 'بشرٌ', 'يئنّونَ', 'من', 'الألمِ'): 0.4369036384607319,
#              ('بشرٌ', 'يئنّونَ', 'من', 'الألمِ', 'human'): 0.4369036384607319,
#              ('يئنّونَ',
#               'من',
#               'الألمِ',
#               'human',
#               'voices'): 0.4369036384607319,
#              ('من',
#               'الألمِ',
#               'human',
#               'voices',
#               'keening'): 0.4369036384607319,
#              ('الألمِ',
#               'human',
#               'voices',
#               'keening',
#               'in'): 0.4369036384607319,
#              ('human', 'voices', 'keening', 'in', 'pain'): 0.4369036384607319,
#              ('voices', 'keening', 'in', 'pain', 'تُشعلُ'): 0.4369036384607319,
#              ('keening',
#               'in',
#               'pain',
#               'تُشعلُ',
#               'أجسادَهُمَ'): 0.4369036384607319,
#              ('in',
#               'pain',
#               'تُشعلُ',
#               'أجسادَهُمَ',
#               'النارُ'): 0.4369036384607319,
#              ('pain',
#               'تُشعلُ',
#               'أجسادَهُمَ',
#               'النارُ',
#               'their'): 0.4369036384607319,
#              ('تُشعلُ',
#               'أجسادَهُمَ',
#               'النارُ',
#               'their',
#               'bodies'): 0.4369036384607319,
#              ('أجسادَهُمَ',
#               'النارُ',
#               'their',
#               'bodies',
#               ','): 0.4369036384607319,
#              ('النارُ',
#               'their',
#               'bodies',
#               ',',
#               'consumed'): 0.4369036384607319,
#              ('their', 'bodies', ',', 'consumed', 'by'): 0.4369036384607319,
#              ('bodies', ',', 'consumed', 'by', 'fire'): 0.4369036384607319,
#              (',', 'consumed', 'by', 'fire', 'light'): 0.4369036384607319,
#              ('consumed', 'by', 'fire', 'light', 'up'): 0.4369036384607319,
#              ('by', 'fire', 'light', 'up', 'the'): 0.4369036384607319,
#              ('fire', 'light', 'up', 'the', 'dark'): 0.4369036384607319,
#              ('light', 'up', 'the', 'dark', '.فيضيئوا'): 0.4369036384607319,
#              ('up', 'the', 'dark', '.فيضيئوا', 'العتمةَ'): 0.4369036384607319,
#              ('the',
#               'dark',
#               '.فيضيئوا',
#               'العتمةَ',
#               'they'): 0.4369036384607319,
#              ('dark',
#               '.فيضيئوا',
#               'العتمةَ',
#               'they',
#               'will'): 0.4369036384607319,
#              ('.فيضيئوا',
#               'العتمةَ',
#               'they',
#               'will',
#               'blame'): 0.4369036384607319,
#              ('العتمةَ', 'they', 'will', 'blame', 'the'): 0.4369036384607319,
#              ('they', 'will', 'blame', 'the', 'early'): 0.4369036384607319,
#              ('will', 'blame', 'the', 'early', 'morning'): 0.4369036384607319,
#              ('blame', 'the', 'early', 'morning', 'hours'): 0.4369036384607319,
#              ('the', 'early', 'morning', 'hours', 'في'): 0.4369036384607319,
#              ('early', 'morning', 'hours', 'في', 'طَيّ'): 0.4369036384607319,
#              ('morning',
#               'hours',
#               'في',
#               'طَيّ',
#               'الكُتْمانِ'): 0.4369036384607319,
#              ('hours', 'في', 'طَيّ', 'الكُتْمانِ', ':'): 0.4369036384607319,
#              ('في', 'طَيّ', 'الكُتْمانِ', ':', 'under'): 0.4369036384607319,
#              ('طَيّ', 'الكُتْمانِ', ':', 'under', 'the'): 0.4369036384607319,
#              ('الكُتْمانِ', ':', 'under', 'the', 'seal'): 0.4369036384607319,
#              (':', 'under', 'the', 'seal', 'of'): 0.4369036384607319,
#              ('under', 'the', 'seal', 'of', 'secrecy'): 0.4369036384607319,
#              ('the', 'seal', 'of', 'secrecy', 'where'): 0.4369036384607319,
#              ('seal', 'of', 'secrecy', 'where', 'there'): 0.4369036384607319,
#              ('of', 'secrecy', 'where', 'there', 'was'): 0.4369036384607319,
#              ('secrecy', 'where', 'there', 'was', 'no'): 0.4369036384607319,
#              ('where', 'there', 'was', 'no', 'sunrise'): 0.3040609569215052,
#              ('there', 'was', 'no', 'sunrise', 'though'): 0.4369036384607319,
#              ('was', 'no', 'sunrise', 'though', 'moon'): 0.4369036384607319,
#              ('no', 'sunrise', 'though', 'moon', 'tells'): 0.4369036384607319,
#              ('sunrise', 'though', 'moon', 'tells', 'me'): 0.4369036384607319,
#              ('though', 'moon', 'tells', 'me', 'god'): 0.4369036384607319,
#              ('moon', 'tells', 'me', 'god', 'is'): 0.4369036384607319,
#              ('tells', 'me', 'god', 'is', 'love'): 0.4369036384607319,
#              ('me', 'god', 'is', 'love', 'unconditional'): 0.4369036384607319,
#              ('god', 'is', 'love', 'unconditional', '.'): 0.4369036384607319,
#              ('is', 'love', 'unconditional', '.', 'i'): 0.4369036384607319,
#              ('love', 'unconditional', '.', 'i', 'ten'): 0.4369036384607319,
#              ('unconditional',
#               '.',
#               'i',
#               'ten',
#               'thousand'): 0.4369036384607319,
# ...
#               'sprouting',
#               'leaves',
#               'for',
#               'spring—'): 0.4369036384607319,
#              ('sprouting',
#               'leaves',
#               'for',
#               'spring—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('leaves',
#               'for',
#               'spring—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('for',
#               'spring—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('spring—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i',
#               'am'): 0.7563075736261741,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i',
#               'am',
#               'flowing'): 0.18907972954576396,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i',
#               'am',
#               'flowing',
#               'water—'): 0.4369036384607319,
#              ('i',
#               'am',
#               'flowing',
#               'water—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('am',
#               'flowing',
#               'water—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('flowing',
#               'water—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('water—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i',
#               'am',
#               'a'): 0.18907937204214878,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i',
#               'am',
#               'a',
#               'community'): 0.4369036384607319,
#              ('i', 'am', 'a', 'community', 'garden'): 0.4369036384607319,
#              ('am', 'a', 'community', 'garden', 'overrun'): 0.4369036384607319,
#              ('a', 'community', 'garden', 'overrun', 'by'): 0.4369036384607319,
#              ('community',
#               'garden',
#               'overrun',
#               'by',
#               'aphids'): 0.4369036384607319,
#              ('garden', 'overrun', 'by', 'aphids', 'in'): 0.4369036384607319,
#              ('overrun', 'by', 'aphids', 'in', 'bloom—'): 0.4369036384607319,
#              ('by',
#               'aphids',
#               'in',
#               'bloom—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('aphids',
#               'in',
#               'bloom—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200bone'): 0.4369036384607319,
#              ('in',
#               'bloom—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200bone',
#               'day'): 0.4369036384607319,
#              ('bloom—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200bone',
#               'day',
#               'i'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200bone',
#               'day',
#               'i',
#               'decay'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200bone',
#               'day',
#               'i',
#               'decay',
#               'and'): 0.4369036384607319,
#              ('day', 'i', 'decay', 'and', 'the'): 0.4369036384607319,
#              ('i', 'decay', 'and', 'the', 'next'): 0.4369036384607319,
#              ('decay', 'and', 'the', 'next', 'i'): 0.4369036384607319,
#              ('and', 'the', 'next', 'i', 'am'): 0.4369036384607319,
#              ('the', 'next', 'i', 'am', 'the'): 0.4369036384607319,
#              ('next', 'i', 'am', 'the', 'moon'): 0.4369036384607319,
#              ('i',
#               'am',
#               'the',
#               'moon',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('am',
#               'the',
#               'moon',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('the',
#               'moon',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('moon',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i',
#               'am',
#               'mountain'): 0.1890790145398855,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i',
#               'am',
#               'mountain',
#               'my'): 0.4369036384607319,
#              ('i', 'am', 'mountain', 'my', 'tears'): 0.4369036384607319,
#              ('am', 'mountain', 'my', 'tears', 'flow'): 0.4369036384607319,
#              ('mountain', 'my', 'tears', 'flow', 'from'): 0.4369036384607319,
#              ('my', 'tears', 'flow', 'from', 'bare'): 0.4369036384607319,
#              ('tears', 'flow', 'from', 'bare', 'stone—'): 0.4369036384607319,
#              ('flow',
#               'from',
#               'bare',
#               'stone—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('from',
#               'bare',
#               'stone—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('bare',
#               'stone—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('stone—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200bmy'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200bmy',
#               'body'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200bmy',
#               'body',
#               'is'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200bmy',
#               'body',
#               'is',
#               'rock'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200bmy',
#               'body',
#               'is',
#               'rock',
#               'and'): 0.4369036384607319,
#              ('body', 'is', 'rock', 'and', 'dust—'): 0.4369036384607319,
#              ('is',
#               'rock',
#               'and',
#               'dust—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('rock',
#               'and',
#               'dust—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('and',
#               'dust—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('dust—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i',
#               'am',
#               'ascendant—'): 0.18907865703897409,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'i',
#               'am',
#               'ascendant—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('i',
#               'am',
#               'ascendant—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('am',
#               'ascendant—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b'): 0.4369036384607319,
#              ('ascendant—',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'the'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'the',
#               'sky'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'the',
#               'sky',
#               'i'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b\u200b',
#               'the',
#               'sky',
#               'i',
#               'want'): 0.4369036384607319,
#              ('the', 'sky', 'i', 'want', 'is'): 0.4369036384607319,
#              ('sky', 'i', 'want', 'is', 'blue'): 0.4369036384607319,
#              ('i', 'want', 'is', 'blue', '.'): 0.4369036384607319,
#              ('want',
#               'is',
#               'blue',
#               '.',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200ba'): 0.4369036384607319,
#              ('is',
#               'blue',
#               '.',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200ba',
#               'note'): 0.4369036384607319,
#              ('blue',
#               '.',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200ba',
#               'note',
#               ':'): 0.4369036384607319,
#              ('.',
#               '\u200b\u200b\u200b\u200b\u200b\u200b\u200ba',
#               'note',
#               ':',
#               'this'): 0.4369036384607319,
#              ('\u200b\u200b\u200b\u200b\u200b\u200b\u200ba',
#               'note',
#               ':',
#               'this',
#               'cento'): 0.4369036384607319,
#              ('note', ':', 'this', 'cento', 'features'): 0.4369036384607319,
#              (':', 'this', 'cento', 'features', 'at'): 0.4369036384607319,
#              ('this', 'cento', 'features', 'at', 'least'): 0.4369036384607319,
#              ('cento', 'features', 'at', 'least', 'one'): 0.4369036384607319,
#              ('features', 'at', 'least', 'one', 'line'): 0.4369036384607319,
#              ('at', 'least', 'one', 'line', 'from'): 0.4369036384607319,
#              ('least', 'one', 'line', 'from', 'every'): 0.4369036384607319,
#              ('one', 'line', 'from', 'every', 'writer'): 0.4369036384607319,
#              ('line', 'from', 'every', 'writer', 'whose'): 0.4369036384607319,
#              ('from', 'every', 'writer', 'whose', 'work'): 0.4369036384607319,
#              ('every',
#               'writer',
#               'whose',
#               'work',
#               'appears'): 0.4369036384607319,
#              ('writer', 'whose', 'work', 'appears', 'in'): 0.4369036384607319,
#              ('whose', 'work', 'appears', 'in', 'i'): 0.4369036384607319,
#              ('work', 'appears', 'in', 'i', 'want'): 0.4369036384607319,
#              ('appears', 'in', 'i', 'want', 'sky'): 0.4369036384607319,
#              ('in', 'i', 'want', 'sky', ','): 0.4369036384607319,
#              ('i', 'want', 'sky', ',', 'a'): 0.4369036384607319,
#              ('want', 'sky', ',', 'a', 'journal'): 0.4369036384607319,
#              ('sky', ',', 'a', 'journal', 'the'): 0.4369036384607319,
#              ...})

# %% [markdown]
# ## Perplexity

# %%
def calculate_perplexity(test_tokens, ngram_probabilities, n):
    """Calculates the perplexity of a test corpus given n-gram probabilities."""
    log_probability_sum = 0
    ngram_count = 0
    
    for i in range(len(test_tokens)-n+1):
        ngram = tuple(test_tokens[i:i+n])
        log_probability_sum += math.log2(ngram_probabilities[ngram])
        ngram_count += 1
    
    average_log_probability = -log_probability_sum / ngram_count
    perplexity = math.pow(2, average_log_probability)
    
    return perplexity

# %%
calculate_perplexity(tokens, ngram_probabilities, n)
# Out:
# 2.3928231961111854

# %%
def greedy_sampling(context, vocab, ngram_probabilities, n, max_length = 50):
    
    sentence = []

    if len(context) < (n-1):
        print("len(context) < n")
        return sentence

    context = context[-(n-1):]
    
    for i in range(max_length):

        probs = dict()
        
        for v in vocab:

            ngram = list(context)
            ngram.append(v)
            ngram = tuple(ngram)
            probs[v] = ngram_probabilities[ngram]

        best_token = max(probs, key=probs.get) # greedy 
        #print(best_v)
        #print(probs[best_v])
        
        if probs[best_token] == 0:
            print("prob = 0")
            return sentence
            
        sentence.append(best_token)
        context = list(context)[1:]
        context.append(best_token)
        context = tuple(context)
            
    return sentence

# %%
context = ['sunday','we','lay','hands','on']
n_values = range(1, 7)  # Iterate n from 1 to 6
for n in n_values:
    print(f"{n}-gram :\n")
    k = 0.00001  # Smoothing parameter k
    
    # Calculate n-gram probabilities
    ngram_probabilities = calculate_ngram_probabilities(df_kaggle_poem_dataset, 'poem', n, k)
    
    # Generate sentence using greedy sampling
    sentence = greedy_sampling(context, vocab, ngram_probabilities, n, max_length=200)
    
    # Print the context and generated sentence
    print(" ".join(context) + " " + " ".join(sentence))
    print("\n")
# Out:
# 1-gram :
#
# prob = 0
# sunday we lay hands on
#
#
# 2-gram :
#
# sunday we lay hands on the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and
#
#
# 3-gram :
#
# sunday we lay hands on the floor , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and the world , and
#
#
# 4-gram :
#
# sunday we lay hands on a girl of ten hand on hand on cornsilk hair . we sing the secret language sung the day the pup placidly lay under cobs of laburnum blossom . each morning the pup had jumped its fence and roamed . the man who is darker than me , but i ’ m not sure whether to sleep is to be seen , and beyond that , a city . a horse released of the traces forgets the weight of the child , who lived in the house of the great pacific ocean ; and of the strange things that befell ; and in the morning , the sun , and the wind , the water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water , the dreamt eye of water ,
#
#
# 5-gram :
#
# sunday we lay hands on a girl of ten hand on hand on cornsilk hair . we sing the secret language sung the day the tin roof of the tower beat on god ’ s floorboard he got cramp in heaven . like our crying and our fornicating so close to his bed was so many shrill mice in a pretty pine floor . to heal the girl with the crippled up leg god sends back the song he took and down it comes contrary in one mouth as fire gentle on our bodies as rain . soft rain swells the cumberland and all her fields in april nuzzles buttercups the mules won ’ t touch the crowpoison the wake-robin the bluets of the field . '' so dame and damsel glitter 'd at the feast variously gay : for he that tells the tale liken 'd them , saying , be fruitful , multiply , and in the center strip mallthe trees are allexcited to be beginning.my girlfriend ’ s amazing waxing keeps grinning.it ’ s enough to fill my plate . a bell rings , like the gong that marks the start of a fight . it ’ s not that i ’
#
#
# 6-gram :
#
# sunday we lay hands on a girl of ten hand on hand on cornsilk hair . we sing the secret language sung the day the tin roof of the tower beat on god ’ s floorboard he got cramp in heaven . like our crying and our fornicating so close to his bed was so many shrill mice in a pretty pine floor . to heal the girl with the crippled up leg god sends back the song he took and down it comes contrary in one mouth as fire gentle on our bodies as rain . soft rain swells the cumberland and all her fields in april nuzzles buttercups the mules won ’ t touch the crowpoison the wake-robin the bluets of the field . every song got a beat beneath . start with the whippoorwill early meadow colors creep into the sky . my sons made this tobacco sled i prime with the jenny toss the last of the sandlugs for the rest to thrive . so hot the wasps hang on the honeysuckle too spent to buzz a sermon . i know my song remembers what my fathers told their strings . driskill , kentuckydriskill , kentucky o transient voyager of heaven
